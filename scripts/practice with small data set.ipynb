# %%
from pymongo import MongoClient
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
CV = CountVectorizer()
from scipy.sparse import csr_matrix
from PodcastFeatureEngineering import Podcast_Features
import graphlab as gl
from graphlab import SFrame as sf

# %%
# final = CV.fit_transform(the_list)
# final = final.toarray()
# final.shape
# a = np.sum(final, axis=0)
# a[a>1]

# %%
client = MongoClient()
# Access/Initiate Database
db = client['Podcast']
# Access/Initiate Table
Podcast_twitter = db['PodcastTwitter_handles']
print Podcast_twitter.count()
# Out:
# 153497

# %%
gl.set_runtime_config("GRAPHLAB_CACHE_FILE_LOCATIONS", "/mnt/data/")
# Out:
# 2016-04-16 16:38:38,673 [INFO] graphlab.cython.cy_server, 176: GraphLab Create v1.8.5 started. Logging: /tmp/graphlab_server_1460824717.log
# This non-commercial license of GraphLab Create is assigned to crystal.humphries@systemsbiology.org and will expire on November 04, 2016. For commercial licensing options, visit https://dato.com/buy/.

# %%
def count_account_with_twitter_handle(pymongo_collection):
    n = 0
    for pod in pymongo_collection.find({}, {'Podcast_Twitter_handle': 1, '_id':0}):
        if 'Podcast_Twitter_handle' in pod and pod['Podcast_Twitter_handle'] != "NaN":
            n+=1
    return n

# %%
def return_account_with_twitter_handle(pymongo_collection):
    Podcast_Twitter_handles=[]
    _id=[]
    for pod in pymongo_collection.find({}, {'Podcast_Twitter_handle': 1, '_id':1}):
        if 'Podcast_Twitter_handle' in pod and pod['Podcast_Twitter_handle'] != "NaN":
            Podcast_Twitter_handles.append(pod['Podcast_Twitter_handle'])
            _id.append(pod['_id'])           
    return pd.DataFrame([Podcast_Twitter_handles, _id])

# %%
Podcast_twitter.find_one({}, {'Podcast_Twitter_handle': 1, '_id':1})

# %%
count_account_with_twitter_handle(Podcast_twitter), Podcast_twitter.count()

# %%
new_df = return_account_with_twitter_handle(Podcast_twitter)
new_df.columns = ['Handles', "IDs"]
new_df.to_pickle("twitter_handles_ids_4Mongo.pkl")
new_df.head()

# %%
practice = []
n=0
for pod in Podcast_twitter.find({}, {'Title':1, '_id':0, 'TwitterFollowers':1}):
    try:
        if 'TwitterFollowers' in pod and pod['TwitterFollowers'] and pod['TwitterFollowers'][0]!='None':
            practice.append(pod)
            n+=1
    except:
        pass
print n
# Out:
# 14444

# %%
import os

# %%
os.environ['PYTHONPATH']

# %%
def create_sparse_matrix(list_of_followers):
    list_of_strings = []
    list_of_titles = []
    for ls in list_of_followers:
        x = ' '.join([ str(x) for x in ls['TwitterFollowers']])
        list_of_strings.append(x)
        list_of_titles.append(ls['Title'])
    return list_of_strings, list_of_titles

# %%
# %%writefile get_sparsematrix.py

from pymongo import MongoClient
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
CV = CountVectorizer()
from scipy.sparse import csr_matrix
from PodcastFeatureEngineering import Podcast_Features
import graphlab as gl

client = MongoClient()
# Access/Initiate Database
db = client['Podcast']
# Access/Initiate Table
Podcast_twitter = db['PodcastTwitter_handles']
print Podcast_twitter.count()

practice = []
n=0
for pod in Podcast_twitter.find({}, {'Title':1, '_id':0, 'TwitterFollowers':1}):
    try:
        if 'TwitterFollowers' in pod and pod['TwitterFollowers'] and pod['TwitterFollowers'][0]!='None':
            practice.append(pod)
            n+=1
    except:
        pass
print n


def create_sparse_matrix(list_of_followers):
    list_of_strings = []
    list_of_titles = []
    for ls in list_of_followers:
        x = ' '.join([ str(x) for x in ls['TwitterFollowers']])
        list_of_strings.append(x)
        list_of_titles.append(ls['Title'])
    return list_of_strings, list_of_titles


strings,titles = create_sparse_matrix(practice)
final = CV.fit_transform(strings)

a = csr_matrix.sum(final, axis=0)
a = np.array(a).reshape(a.shape[1],)
sparse = final.toarray()
mask = a>1
indices=np.where(mask)[0]
mat = sparse_mat.tocsc()[:,indices]
df = mat.toarray()
df = pd.DataFrame(df)
item_matrix=gl.SFrame(df)

item_matrix.save("IHavebeensaved.gl")

# %%
df = pd.DataFrame(practice)
df.to_pickle("twitter_info.pkl")

# %%
strings,titles = create_sparse_matrix(practice)
final = CV.fit_transform(strings)
a = csr_matrix.sum(final, axis=0)
print final.shape
a = np.array(a).reshape(a.shape[1],)
mask = a>1
# Out:
# (14444, 1683606)

# %%
sum(mask)

# %%
u=np.where(mask)[0]

# %%
len(u)

# %%
sparse_mat = final.tocsc()[:,u]

# %%
mat = sparse_mat.toarray()

# %%
def get_truncated_matrix(mat, max_num):
    df = pd.DataFrame(mat[:,0:max_num])
    df.index = titles
    a = df.sum(axis=1)
    mask2 = a>0
    return df.loc[mask2,:]

# %%
df = pd.DataFrame(mat[:,0:5000])

# %%
sum(mask2)
# Out:
# 7335

# %%
df.loc[mask2,:]
# Out:
#                                                     0     1     2     3     \
# Kraft Kitchens Recipe Videos                           0     0     0     0
# HG World                                               0     0     0     0
# Radio Classic                                          0     0     0     0
# Calvary Mill Creek                                     0     0     0     0
# Saturday Stories                                       0     0     0     0
# Jean Lostebien : Mix-Tape Official Podcast             0     0     0     0
# Moonbeam Music Podcast                                 0     0     0     0
# Sparetime Radio                                        0     0     0     0
# Kávička s Michalem                                     0     0     0     0
# Invasion Podcast                                       0     0     0     0
# Concepts In Code                                       0     0     0     0
# ALTTAB Radio                                           0     0     0     0
# DJ Brent - Music that makes you move                   0     0     0     0
# Below The Bible Belt                                   0     0     0     0
# Mick Shane Rock Show                                   0     0     0     0
# FulfilledRadio                                         0     0     0     0
# Hall of Geeks                                          0     0     0     0
# Serg Tachini                                           0     0     0     0
# Invasion of the Podcast!                               0     0     0     0
# Liberty Grace Church - Sermons                         0     0     0     0
# Architectural Lighting Design Defined                  0     0     0     0
# Martha Stewart                                         0     0     0     0
# The Jazzy Vegetarian                                   0     0     0     0
# Merriam-Webster's Word of the Day                      0     0     0     0
# African-American History Month with the Univers...     0     0     0     0
# VOICEMAIL POEMS                                        0     0     0     0
# AudioFile Magazine                                     0     0     0     0
# Snap Judgment                                          0     0     0     0
# Drama of the Week                                      0     0     0     0
# The Collective Podcast                                 0     0     0     0
# ...                                                  ...   ...   ...   ...
# What Is Wrong with UX? - Users Know                    0     0     0     0
# Whitby Christian Fellowship Podcast                    0     0     0     0
# Veravo Podcast: Online Marketing | SEO | PPC           0     0     0     0
# ASHA MINUTE MEN                                        0     0     0     0
# Client Crusher Academy                                 0     0     0     0
# Guardian short stories podcast                         0     0     0     0
# 3 Geeks in a Pod                                       0     0     0     0
# Get4x Blog Podcast                                     0     0     0     0
# Pleasant Valley Baptist Church :: Indian Land, SC      0     0     0     0
# Citizens of Metropolis !                               0     0     0     0
# Creatively Speaking                                    0     0     0     0
# Daily Inspirations Podcast                             0     0     0     0
# 1 Question Podcast                                     0     0     0     0
# John vs Patrick                                        0     0     0     0
# Sky Island (version 2) by BAUM, L. Frank               0     0     0     0
# Misdirected Mark Productions                           0     0     0     0
# Second Balcony Breakdown                               0     0     0     0
# NRK – Kulturnytt                                       0     0     0     0
# Launch Financial with Brad Sherman                     0     0     0     0
# Starr Mix                                              0     0     0     0
# 30minuteweek                                           0     0     0     0
# \r\nSports - Jacksonville.com                          0     0     0     0
# Boston Globe Next Stop: Things To Do around Sub...     0     0     0     0
# Small Business Podcast                                 0     0     0     0
# GiDa                                                   0     0     0     0
# Knee Deep In Play                                      0     0     0     0
#
#                                                     8     9     ...   4990  \
# Kraft Kitchens Recipe Videos                           0     0  ...      0
# HG World                                               0     0  ...      0
# Radio Classic                                          0     0  ...      0
# Calvary Mill Creek                                     0     0  ...      0
# Saturday Stories                                       0     0  ...      0
# Jean Lostebien : Mix-Tape Official Podcast             0     0  ...      0
# Moonbeam Music Podcast                                 0     0  ...      0
# Sparetime Radio                                        0     0  ...      0
# Kávička s Michalem                                     0     0  ...      0
# Invasion Podcast                                       0     0  ...      0
# Concepts In Code                                       0     0  ...      0
# ALTTAB Radio                                           0     0  ...      0
# DJ Brent - Music that makes you move                   0     0  ...      0
# Below The Bible Belt                                   0     0  ...      0
# Mick Shane Rock Show                                   0     0  ...      0
# FulfilledRadio                                         0     0  ...      0
# Hall of Geeks                                          0     0  ...      0
# Serg Tachini                                           0     0  ...      0
# Invasion of the Podcast!                               0     0  ...      0
# Liberty Grace Church - Sermons                         0     0  ...      0
# Architectural Lighting Design Defined                  0     0  ...      0
# Martha Stewart                                         0     0  ...      0
# The Jazzy Vegetarian                                   0     0  ...      0
# Merriam-Webster's Word of the Day                      0     0  ...      0
# African-American History Month with the Univers...     0     0  ...      0
# VOICEMAIL POEMS                                        0     0  ...      0
# AudioFile Magazine                                     0     0  ...      0
# Snap Judgment                                          0     0  ...      0
# Drama of the Week                                      0     0  ...      0
# The Collective Podcast                                 0     0  ...      0
# ...                                                  ...   ...  ...    ...
# Fuzzy Logic Science Show                               0     0  ...      0
# Work @ Home RockStar Podcast                           0     0  ...      0
# Sales Training For The Masses!                         0     0  ...      0
# All Too Human Podcast                                  0     0  ...      0
# What Is Wrong with UX? - Users Know                    0     0  ...      0
# Whitby Christian Fellowship Podcast                    0     0  ...      0
# Out:
# (12838, 50000)

# %%
start = time.time()
newnewdf=gl.SFrame(attempt)
end = time.time()
print(end - start)

# %%
newnewdfnewdf.save("sf_50000.gl")

# %%
attempt = get_truncated_matrix(mat, 100000)
print attempt.shape
start = time.time()
newnewdf=gl.SFrame(attempt)
end = time.time()
print(end - start)
newnewdfnewdf.save("sf_100000.gl")

# %%
def get_data(x):
    strings,titles = create_sparse_matrix(x)
    f = CV.fit_transform(strings)
    sf=pd.DataFrame(f.toarray())
    sf = gl.SFrame(sf)
    return sf

# %%
start=0
list_sf = []
for stop in range(1000,11000,1000):
    if stop > len(practice):
        stop = len(practice)
    x = practice[start:stop]
    list_sf.append(get_data(x))
    start = stop

# %%
import time
start = time.time()
x = practice[0:100]
end = time.time()
print(end - start)
# Out:
# 0.00016713142395

# %%
strings,titles = create_sparse_matrix(x)

# %%
f = CV.fit_transform(strings)

# %%
sf=pd.DataFrame(f.toarray())

# %%
sf.head()

# %%
sf = gl.SFrame(sf)
sf.head()

# %%
user_matrix = gl.SFrame(newnewdf)
user_matrix.save("user_twitter_pod.gl")

# %%
item_matrix = gl.SFrame(newnewdf)

# %% [markdown]
# ## Creation of a Model

# %%
MFR = gl.recommender.factorization_recommender

# %%
mfr_sd = MFR.create(X_train,
                 item_id='movie_id',
                 target='rating',
                 user_data=user_data,
                 item_data=movie_simple,
                 solver='sgd',
                 linear_regularization=1e-09,
                 regularization=1e-07,
                 num_factors=20)

# %%
PF = Podcast_Features()
df2 = PF.cleaned_df.copy()

# %%
df2 = pd.read_pickle('df2.pkl')

# %%
PF = Podcast_Features(cleaned_df=df2)
df2.to_pickle("df2.pkl")
df2['Subtitle_categories'] = PF.get_new_column_of_text('iTunesSubtitle', n_components=30)
df2.to_pickle("df2.pkl")
df2['Keywords_categories'] = PF.get_new_column_of_text('iTunesKeywords', n_components=30)
df2['Url_Folders'] = df2.NormalizedUrl.apply(lambda x: x.count('/'))
df2.to_pickle("df2.pkl")

# %%
#df2['Summary_categories'] = PF.get_new_column_of_text('iTunesSummary', n_components=30)
#df2.to_pickle("df2.pkl")

#for some reason this data kills the kernel

# %%
dates=[]
for a,b in  zip(df2.DateLastEpisode, df2.DateFirstEpisode):
    try:
        new = (a-b).days
    except:
        new = 'NaT'
    dates.append(new)
dates = np.array(dates)

# %%
df2['dates'] = dates

# %%
g = df2.columns.to_series().groupby(df2.dtypes).groups

# %%
c = g.keys()
c

# %%
df3 = df2.drop(g[c[0]], axis=1)
df3 = df3.drop(g[c[1]], axis=1)
df3['Title'] = df2.Title

# %%
df3.info()

# %%
ISR = gl.recommender.item_similarity_recommender.ItemSimilarityRecommender #SEAFREE

# %%
df2_gl = gl.SFrame(df3)

# %%
df3.

# %%
??gl.item_similarity_recommender.create

# %%
IS = gl.item_similarity_recommender.create(df2_gl, user_id='Title', item_id='CategoryRanking')

# %%
IS.get_similar_users() #(users=['The Moth Podcast'])

# %%
df3.Title
